# %% [markdown]
# <a href="https://colab.research.google.com/github/smandava22/python/blob/module-4/graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y)
plt.show()

# %% [markdown]
# #Plotting x and y points

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,'o')
plt.show() #line graph

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(y)
plt.show()

# %% [markdown]
# #Markers

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color='blue',marker='*')
plt.show() #line graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color='blue',marker='o')
plt.show() #line graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])

plt.plot(x,y,'o:r',color='blue',marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color='blue',marker='o',ms=20)
plt.show() #line graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color='blue',marker='o',ms=20,mec='r')
plt.show() #line graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color='blue',marker='o',ms=20,mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color='blue',marker='o',ms=20,mec='r',mfc='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color='blue',marker='o',ms=20,mec='hotpink',mfc='hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color='blue',marker='o',ms=20,mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %% [markdown]
# #Linestyle

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,ls='dashed',color='blue')
plt.show()#dashed line graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,linestyle='dotted',color='blue')
plt.show()#dashed line graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color = '#4CAF50')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,color = 'hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.plot(x,y,linewidth = '20.5')
plt.show()

# %% [markdown]
# #labels

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.xlabel("subjects")
plt.ylabel("marks")
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.title("sem 1 marks")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
font1 = {'color':'blue','size':20}
font2 = {'color':'darkred','size':15}
plt.title("sem 1 marks",fontdict = font1)
plt.xlabel("subjects",fontdict = font2)
plt.ylabel("marks",fontdict = font2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
font1 = {'color':'blue','size':20}
font2 = {'color':'darkred','size':15}
plt.title("sem 1 marks",fontdict = font1,loc = 'left')
plt.xlabel("subjects",fontdict = font2)
plt.ylabel("marks",fontdict = font2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# #Grid

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.title("sem 1 marks")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.plot(x, y)
plt.grid()
plt.show()#line graph with grid

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.title("sem 1 marks")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.plot(x, y)
plt.grid()
plt.grid(axis = 'x')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.title("sem 1 marks")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.plot(x, y)
plt.grid()
plt.grid(axis = 'y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.title("sem 1 marks")
plt.xlabel("subjects")
plt.ylabel("marks")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# #Creating Scatter Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])

plt.scatter(x,y)
plt.show()#points graph

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple"])
plt.scatter(x,y,c=colors)
plt.show()#points graph

# %% [markdown]
# #Creating Bars

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])

plt.xlabel("subjects")
plt.ylabel("marks")
plt.bar(x,y,color='hotpink')
plt.show()#bar ghaph with labels

# %% [markdown]
# #Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.hist(y)
plt.show()#histogram

# %% [markdown]
# #Creating Pie Charts

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
a=['sv','sev','c','cl','vdc','eng','it','evpr']
plt.pie(y,labels=a)
plt.show()#pie chart

# %%
x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
a=['sv','sev','c','cl','vdc','eng','it','evpr']
plt.pie(y,labels=a)
plt.legend()
plt.show()#pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
a=['sv','sev','c','cl','vdc','eng','it','evpr']
b=['r','g','b','c','m','y','k','hotpink']
plt.pie(y,labels=a,colors=b)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
a=['sv','sev','c','cl','vdc','eng','it','evpr']
myexplode = [0.4, 0, 0, 0,0,0,0,0]
plt.pie(y, labels =a, explode = myexplode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array(['sv','sev','c','cl','vdc','eng','it','evpr'])
y=np.array([79,56,98,64,46,39,88,93])
plt.barh(x,y,color='hotpink',height=0.8)
plt.show()
